# %% [markdown]
# SOURCE
# https://ram-parameswaran22.medium.com/a-relatively-faster-approach-for-reading-json-lines-file-into-pandas-dataframe-90b57353fd38

# %%
import pandas as pd
import json
import seaborn as sns
from wordcloud import WordCloud
import PIL
import itertools
import matplotlib.pyplot as plt

# %%
df = pd.read_json('Digital_Music_5.json.gz', lines=True)

# %%
df
# Out:
#         overall  vote  verified   reviewTime      reviewerID        asin  \
# 0             5   3.0      True   06 3, 2013  A2TYZ821XXK2YZ  3426958910
# 1             5   NaN      True  10 11, 2014  A3OFSREZADFUDY  3426958910
# 2             5   NaN      True  02 11, 2014  A2VAMODP8M77NG  3426958910
# 3             4   3.0     False   12 7, 2013   AAKSLZ9IDTEH0  3426958910
# 4             5   NaN      True  06 12, 2016  A3OH43OZJLKI09  5557706259
# ...         ...   ...       ...          ...             ...         ...
# 169776        5   NaN      True  08 19, 2018  A1SR2T84IXOMAQ  B01HJ91MTW
# 169777        5   NaN      True  03 18, 2018  A2SR3DWJR1PYR6  B01HJ91MTW
# 169778        5   NaN      True   03 7, 2018  A24V7X30NIMOIY  B01HJ91MTW
# 169779        5   NaN      True  02 12, 2018  A1LW10GYP2EYM1  B01HJ91MTW
# 169780        5   NaN      True  01 27, 2018  A26TH3YW0QWPI7  B01HJ91MTW
#
#                             style       reviewerName  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169781 entries, 0 to 169780
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   overall         169781 non-null  int64
#  1   vote            7611 non-null    float64
#  2   verified        169781 non-null  bool
#  3   reviewTime      169781 non-null  object
#  4   reviewerID      169781 non-null  object
#  5   asin            169781 non-null  object
#  6   style           157989 non-null  object
#  7   reviewerName    169776 non-null  object
#  8   reviewText      169623 non-null  object
#  9   summary         169745 non-null  object
#  10  unixReviewTime  169781 non-null  int64
#  11  image           182 non-null     object
# dtypes: bool(1), float64(1), int64(2), object(8)
# memory usage: 14.4+ MB

# %%
five_stars = df[df['overall'] == 5]

# %%
four_stars = df[df['overall'] == 4]

# %%
three_stars = df[df['overall'] == 3]

# %%
two_stars = df[df['overall'] == 2]

# %%
one_stars = df[df['overall'] == 1]

# %%
not_verfified = five_stars[five_stars[]]

# %%
text = five_stars['reviewText'].values 

wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
text = four_stars['reviewText'].values 

wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
text = three_stars['reviewText'].values 

wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
text = two_stars['reviewText'].values 

wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
text = one_stars['reviewText'].values 

wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
five_stars['totalwords'] = five_stars['reviewText'].str.count(' ') + 1
# Out:
# C:\Users\doube\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
five_stars
# Out:
#         overall  vote  verified   reviewTime      reviewerID        asin  \
# 0             5   3.0      True   06 3, 2013  A2TYZ821XXK2YZ  3426958910
# 1             5   NaN      True  10 11, 2014  A3OFSREZADFUDY  3426958910
# 2             5   NaN      True  02 11, 2014  A2VAMODP8M77NG  3426958910
# 4             5   NaN      True  06 12, 2016  A3OH43OZJLKI09  5557706259
# 6             5   NaN      True   06 6, 2015  A20Z0JD766DPG6  5557706259
# ...         ...   ...       ...          ...             ...         ...
# 169776        5   NaN      True  08 19, 2018  A1SR2T84IXOMAQ  B01HJ91MTW
# 169777        5   NaN      True  03 18, 2018  A2SR3DWJR1PYR6  B01HJ91MTW
# 169778        5   NaN      True   03 7, 2018  A24V7X30NIMOIY  B01HJ91MTW
# 169779        5   NaN      True  02 12, 2018  A1LW10GYP2EYM1  B01HJ91MTW
# 169780        5   NaN      True  01 27, 2018  A26TH3YW0QWPI7  B01HJ91MTW
#
#                             style       reviewerName  \
# ...

# %%
Non_v_five_stars = five_stars[five_stars['verified']== False]

# %%
non_v_df = df[df['verified']== False]

# %%
non_v_df['totalwords'] = non_v_df['reviewText'].str.count(' ') + 1
# Out:
# C:\Users\doube\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
non_v_df_1 =non_v_df[non_v_df['totalwords']<=5]

# %%
non_v_df_1['reviewerID'].value_counts().head(40)
# Out:
# AIZWM3J1HG027     28
# A1VLJIGQNNCTL5    25
# ANSO2ODK8EN5      25
# AILI31O5KVSKK     22
# AZ7IXJZ79RMCC     17
# A3QJDL2IQKHXWW    16
# AYSK041A5VV89     14
# A2SCOJ1GOVKJ1Z    13
# A3K37O1380ZLXW    13
# A24GF60I5H7WJJ    12
# A2SI9C9XZLU00M    12
# AJFNEL0DBQ42M     11
# A2RPB8RGY6DINF    11
# A17H0848XMVGBP    11
# A2WC24DWP57F8K    10
# A25HMVL101P0RT    10
# A3DSFZ2F8FXV20    10
# AFRVJQ9TEMS08     10
# A34IBZYHGIIFZA    10
# A2UDKT29ON9UZE    10
# A2BIO5G68XWND5     9
# A2341V07DRDSC      9
# A1QREJX34KNYS1     8
# AOZCT7C19SKVK      8
# AHZAR4F9Y25RO      8
# A3471M3LYN8MVQ     7
# A3HDREYV273WYK     7
# A174ZAJY9Q416B     7
# A1S3CZRIPURGBN     7
# A1MTVCGAP6CBJH     7
# A7UH5YGIKEFR3      7
# A3BEZFDYU1KM6A     7
# A1XEHP4RW0N53P     7
# A37M24GZ63ISK8     6
# A3NSN2F784GPIF     6
# A2ZC8NJH3ZFM4H     6
# A3JIH8AAZLQQ4O     6
# AKX9H310VDNQ5      6
# A2ANZYE6HTIUAO     6
# A36WR9V545L6WJ     6
# Name: reviewerID, dtype: int64

# %%
non_v_df_2 = non_v_df_1[non_v_df_1['reviewerID']== 'AZ7IXJZ79RMCC']

# %%
non_v_df_2
# Out:
#         overall  vote  verified  reviewTime     reviewerID        asin  \
# 121143        5   NaN     False  04 6, 2018  AZ7IXJZ79RMCC  B000SXITMK
# 121173        5   NaN     False  04 6, 2018  AZ7IXJZ79RMCC  B000SXKXHY
# 121189        5   NaN     False  04 6, 2018  AZ7IXJZ79RMCC  B000SXHII6
# 135963        5   NaN     False  04 6, 2018  AZ7IXJZ79RMCC  B00137GDW8
# 137059        5   NaN     False  04 6, 2018  AZ7IXJZ79RMCC  B00137KOPK
# 137071        5   NaN     False  04 6, 2018  AZ7IXJZ79RMCC  B00137O5Z0
# 139931        5   NaN     False  04 6, 2018  AZ7IXJZ79RMCC  B0013CW9TO
# 141249        5   NaN     False  04 6, 2018  AZ7IXJZ79RMCC  B0016CRVSU
# 141507        5   NaN     False  04 6, 2018  AZ7IXJZ79RMCC  B00187TWY4
# 143479        5   NaN     False  04 6, 2018  AZ7IXJZ79RMCC  B001FJ2JAE
# 144716        5   NaN     False  04 6, 2018  AZ7IXJZ79RMCC  B001KVVI04
# 147576        5   NaN     False  04 6, 2018  AZ7IXJZ79RMCC  B001VSX37W
# ...

# %%
text = non_v_df_2['reviewText'].values 

wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
Non_v_five_stars_1 = Non_v_five_stars[Non_v_five_stars['totalwords']<5]

# %%
Non_v_five_stars_1
# Out:
#         overall  vote  verified   reviewTime      reviewerID        asin  \
# 15            5   NaN     False  09 25, 2016  A2WC24DWP57F8K  5559166928
# 20            5   NaN     False  11 11, 2014   A33HHL9IUCK2C  5559166928
# 21            5   NaN     False  10 18, 2014   AJCC7PGJWTO7A  5559166928
# 695           5   NaN     False   07 8, 2014  A3BHP9OXQFM360  B000S51XMQ
# 748           5   NaN     False  11 25, 2015   AV3RNXJZ3SBZ8  B000S5111E
# ...         ...   ...       ...          ...             ...         ...
# 168775        5   NaN     False   05 4, 2016   A7SC6E8SYON8N  B018UY81QW
# 169039        5   NaN     False   05 3, 2018   AUHTKUOOHG7S3  B01B8I3DHO
# 169491        5   NaN     False  02 14, 2018  A1PLKP6LDDUE3Y  B01ENS16MK
# 169743        5   NaN     False  06 26, 2018   A3K0KS34MKAEL  B01HEIQ1JE
# 169747        5   NaN     False  06 26, 2018   A3K0KS34MKAEL  B01HEIPV22
#
#                             style      reviewerName               reviewText  \
# ...

# %%
Non_v_five_stars_1['reviewerID'].value_counts().head(40)
# Out:
# A1VLJIGQNNCTL5    25
# ANSO2ODK8EN5      25
# AILI31O5KVSKK     20
# AZ7IXJZ79RMCC     17
# A3QJDL2IQKHXWW    14
# AIZWM3J1HG027     14
# A3K37O1380ZLXW    13
# AJFNEL0DBQ42M     11
# A17H0848XMVGBP    11
# A3DSFZ2F8FXV20    10
# A2UDKT29ON9UZE    10
# AFRVJQ9TEMS08     10
# A2WC24DWP57F8K    10
# A34IBZYHGIIFZA     9
# A2BIO5G68XWND5     9
# A25HMVL101P0RT     8
# AOZCT7C19SKVK      8
# A2341V07DRDSC      8
# A174ZAJY9Q416B     7
# A24GF60I5H7WJJ     7
# A318FI609EA55I     6
# A37M24GZ63ISK8     6
# A2ANZYE6HTIUAO     6
# A2ZC8NJH3ZFM4H     6
# A35N2NSXFNC2WE     6
# A17RC90N6A89ER     6
# AHZAR4F9Y25RO      6
# AN9AXUWNL1KNQ      6
# A33BCKBRJHSCE6     6
# A1S3CZRIPURGBN     6
# A3NSN2F784GPIF     6
# A1QREJX34KNYS1     6
# A1XEHP4RW0N53P     6
# A1MTVCGAP6CBJH     6
# A3EZOBDMR7DHL6     6
# A3UKPCX0TWUJB4     6
# AKX9H310VDNQ5      6
# A1PHLZYNXAAV31     6
# AHPJLD8YZZ135      6
# AM0VF6RPNH0KL      5
# Name: reviewerID, dtype: int64

# %%
Non_v_five_stars_1['asin'].value_counts().head(40)
# Out:
# B00136LQQ2    10
# B00CZF8B68     8
# B00LWC6P1S     7
# B00BWGHIHY     7
# B0170K9UTO     7
# B00136JL8W     6
# B00G2IAIVK     5
# B00EH49FRE     5
# B00OXE38D0     5
# B00124B8UO     5
# B00121WWXO     5
# B007B6VOII     5
# B00PVC0BKG     5
# B0059H09DC     5
# B0013F48EA     4
# B00136JF8I     4
# B00GJ2N10O     4
# B00137G8MS     4
# B00137QS28     4
# B000W176MM     4
# B0012EESZG     4
# B00CUR29GY     4
# B00137ML5Q     4
# B00137GHF6     4
# B00137XCVS     4
# B00122IPBG     4
# B000WLTDIM     4
# B000T1EJ0W     4
# B00137OA0K     4
# B00JJOG5D4     4
# B00137QMFG     4
# B0013D6QP6     4
# B000VZOAI2     4
# B0011Z4X9C     4
# B00136LELO     4
# B00137RCEQ     4
# B0011Z8O2O     4
# B009KGKF3M     4
# B0092MKTWQ     4
# B000WLH9TM     4
# Name: asin, dtype: int64

# %%
Non_v_five_stars_2 = Non_v_five_stars[Non_v_five_stars['reviewerID']== 'ANSO2ODK8EN5']

# %%
five_stars
# Out:
#         overall  vote  verified   reviewTime      reviewerID        asin  \
# 0             5   3.0      True   06 3, 2013  A2TYZ821XXK2YZ  3426958910
# 1             5   NaN      True  10 11, 2014  A3OFSREZADFUDY  3426958910
# 2             5   NaN      True  02 11, 2014  A2VAMODP8M77NG  3426958910
# 4             5   NaN      True  06 12, 2016  A3OH43OZJLKI09  5557706259
# 6             5   NaN      True   06 6, 2015  A20Z0JD766DPG6  5557706259
# ...         ...   ...       ...          ...             ...         ...
# 169776        5   NaN      True  08 19, 2018  A1SR2T84IXOMAQ  B01HJ91MTW
# 169777        5   NaN      True  03 18, 2018  A2SR3DWJR1PYR6  B01HJ91MTW
# 169778        5   NaN      True   03 7, 2018  A24V7X30NIMOIY  B01HJ91MTW
# 169779        5   NaN      True  02 12, 2018  A1LW10GYP2EYM1  B01HJ91MTW
# 169780        5   NaN      True  01 27, 2018  A26TH3YW0QWPI7  B01HJ91MTW
#
#                             style       reviewerName  \
# ...

# %%
one_stars['totalwords'] = one_stars['reviewText'].str.count(' ') + 1
# Out:
# C:\Users\doube\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Non_v_one_stars = one_stars[one_stars['verified']== False]

# %%
Non_v_one_stars_1 = Non_v_one_stars[Non_v_one_stars['totalwords']<5]

# %%
Non_v_one_stars_1['reviewerID'].value_counts().head(40)
# Out:
# A1SDLTS9NX8FU1    5
# A3HDREYV273WYK    4
# A2MW2RAYI76SSK    2
# AAQAB2HFHYQ4F     2
# AYSK041A5VV89     2
# A3CVAKGCJSDODF    2
# ACMR50HORO60A     2
# AZKXH0J59TK11     1
# A1MPONLR1R6N9M    1
# AAUMLXHKKZNBT     1
# AXHSMI8VFE39H     1
# A2AE6EFRF2MORE    1
# A1NWA695SU4SPS    1
# A10ZTNFSUVSUDS    1
# A3K2N8JMD9OFIR    1
# A3W4AC94KUVDQ7    1
# A5UUKLEXZMJLQ     1
# AN12CK1QJDO5V     1
# A3BEZFDYU1KM6A    1
# A2GHH923VYOGDP    1
# Name: reviewerID, dtype: int64

# %%
Non_v_one_stars_2 = Non_v_one_stars_1[Non_v_one_stars_1['reviewerID']== 'A1SDLTS9NX8FU1']

# %%
Non_v_one_stars_2
# Out:
#         overall  vote  verified  reviewTime      reviewerID        asin  \
# 56668         1   NaN     False  02 9, 2016  A1SDLTS9NX8FU1  B001KQFZWQ
# 56767         1   NaN     False  02 9, 2016  A1SDLTS9NX8FU1  B001KQJWAM
# 87314         1   2.0     False  02 9, 2016  A1SDLTS9NX8FU1  B00C10MLXG
# 96147         1   NaN     False  02 9, 2016  A1SDLTS9NX8FU1  B00HFWYA3E
# 139891        1   NaN     False  02 9, 2016  A1SDLTS9NX8FU1  B0013CROJY
#
#                             style reviewerName reviewText   summary  \
# 56668   {'Format:': ' MP3 Music'}           GT     Racist  One Star
# 56767   {'Format:': ' MP3 Music'}           GT     Racist  One Star
# 87314   {'Format:': ' MP3 Music'}           GT     Racist  One Star
# 96147   {'Format:': ' MP3 Music'}           GT     Racist  One Star
# 139891  {'Format:': ' MP3 Music'}           GT     Racist  One Star
#
#         unixReviewTime image  totalwords
# 56668       1454976000   NaN           1
# ...

# %%
df_userid = df.groupby('reviewerID')

# %%
df_userid

# %%
df1 = df['reviewerID'].nunique()
print(df1)
# Out:
# 16566

# %%
df['reviewerID'].value_counts().head(40)
# Out:
# A3W4D8XOGLWUN5    791
# A2H3JURQZOHVMB    314
# A36EDWL4F3AASU    223
# A165P3MOJV3OVZ    219
# AVKHYC2D7MD56     214
# A237E0FTADYM58    189
# AMP7TQRWAIE84     185
# A14YTPQDH3PAZU    165
# A15T3Y3BL2AJ9V    157
# A2KW2KWKABNYNO    149
# A3VWZMMIKPY2XU    143
# A1BVCH82W0M2W2    137
# A2ABJ4XM4MJ5CD    134
# A1OKPC1K12YZEP    131
# ASFQBB524HVRJ     130
# A1GN8UJIZLCA59    128
# A2LDEDOQZH3VTP    126
# A9Q28YTLYREO7     126
# A2UQGX6YMQ5BAL    124
# A2JMRUN0QULNLI    123
# AAT1JT5M65VGQ     121
# A2LTPIQG2RWNJW    121
# A10M52OJSDB8WK    121
# A3GJ6CFWN47N0U    120
# A1RGJA7LQ3B5H7    116
# A2PR1O53J0V8W2    110
# A3W527BN42AXN1    108
# A3KQI694I9KL5L    108
# A1M3F4G45OXRDI    107
# A15JTJXQXO22JJ    107
# A3BIV1X1K9R796    107
# ARYVQL4N737A1     107
# A22PZBENWG6IM0    106
# ABDR6IJ93HFIO     104
# A2UYBXJACYG1N9    104
# A2UFJ5NIT2RFCM    103
# A2RNYF2PTOB82J    102
# A2TTBO023PYYBA    101
# A135GWMXMTR58Z    100
# A21RF3DDGLD40Y     98
# Name: reviewerID, dtype: int64

# %%
Sad_guy = df[df['reviewerID']== 'A3W4D8XOGLWUN5']

# %%
text = Sad_guy['reviewText'].values 

wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show(100)

# %%
Sad_guy['totalwords'] = Sad_guy['reviewText'].str.count(' ') + 1
# Out:
# C:\Users\doube\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
a = Sad_guy['totalwords'].sum()

# %%
a
# Out:
# 134086

# %%
Non_V_Sad_guy = Sad_guy[Sad_guy['verified']== False]

# %%
Non_V_Sad_guy
# Out:
#         overall  vote  verified   reviewTime      reviewerID        asin  \
# 24            4   4.0     False  07 19, 2005  A3W4D8XOGLWUN5  7799420340
# 68            4   7.0     False  12 25, 2009  A3W4D8XOGLWUN5  7799420340
# 797           5   NaN     False  12 23, 2014  A3W4D8XOGLWUN5  B000S52E9W
# 897           5   NaN     False   07 2, 2015  A3W4D8XOGLWUN5  B000S55TTY
# 985           4   NaN     False  01 25, 2014  A3W4D8XOGLWUN5  B000SX87C2
# ...         ...   ...       ...          ...             ...         ...
# 169191        3   NaN     False   06 9, 2016  A3W4D8XOGLWUN5  B01CAGEVCE
# 169204        5   NaN     False  10 27, 2016  A3W4D8XOGLWUN5  B01CBIJ6CG
# 169205        5   NaN     False  07 23, 2016  A3W4D8XOGLWUN5  B01CBIJ6CG
# 169647        2   NaN     False  08 30, 2016  A3W4D8XOGLWUN5  B01FRF0VNS
# 169693        4   NaN     False   09 2, 2016  A3W4D8XOGLWUN5  B01GL0OLHU
#
#                             style    reviewerName  \
# ...
